# %% [markdown]
# <a href="https://colab.research.google.com/github/Championcode2006/Neural-Network/blob/main/Neural_Network.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Importing the needed libraries**

# %%
import numpy as np
import pandas as pd
from matplotlib import pyplot as plt

# %% [markdown]
# Now , for accesing the dataset i will connect the colab to drive
